# %% [markdown]
# <a href="https://colab.research.google.com/github/bimal-bp/Machine_learning_1.0_with_Bimal_TS/blob/ML_MODELS/INTRO_MachineLearning_with_BIMAL_TS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MachineLearning**
# * Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms , Machine learning (ML) is like teaching computers to think 🧠💻. With ML, computers can learn from data, identify patterns, and make predictions or decisions without being told what to do.
#
# *EXPAMPLE*-- ML is the last stage in every case who predits that the message if fraud or not or the man can repay the loan or not
#
# --It's like teaching a computer to think and learn like a human
#
# **Different Types of machine learning**
#
# * supervised,
# * unsupervised,
# * reinforcement learning,
#
# --Evaluation metrics for machine learning models, such as accuracy, precision, recall, F1 score, ROC curve, and AUC.
#
# --ML has many applications 🌎, from speech and image recognition 🎤📷 to recommendation systems 📈👨‍💼 and predictive modeling. ML is revolutionizing the way we work and live!

# %% [markdown]
# ![Screenshot 2023-09-13 091453.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Activity** **1** :
#
# Machine learning allows computers to learn from data, identify ___, and make predictions or decisions without being explicitly programmed to do so.
#
# Machine learning is used in various industries, from healthcare to finance, entertainment to agriculture, helping businesses work smarter and faster, while improving accuracy and reducing ___.
#
# Machine learning can be used to ___ customer behavior, analyze images and videos, and assist doctors in diagnosing diseases.
#
# **ANSWERS**-
#
# 1.Patterns
#
# 2.Errors
#
# 3.Predict

# %% [markdown]
# # **Different types of machine learning **:
#
# *  Supervised learning is like teaching a computer with labeled data 🏷️. The computer learns by example, and makes predictions based on what it has learned. It's like having a teacher guide you every step of the way! 🤓👨‍🏫
#
# *  Unsupervised learning, on the other hand, is like exploring data without any guidance 🤔. The computer looks for patterns and relationships in the data, and makes predictions based on what it finds. It's like exploring a new place without a map! 🌍🗺️
#
# *  Reinforcement learning is like training a computer to learn by trial and error 🤖🎮. The computer learns by interacting with an environment and receives rewards for making good decisions. It's like playing a game and learning from your mistakes! 🏅🕹️
#
# -- Each type of ML has its own strengths and weaknesses, and can be used in different applications 🏭📈. Supervised learning is great for classification and prediction tasks, unsupervised learning is useful for clustering and anomaly detection

# %% [markdown]
# SML.EXAMPLE--
#
# The labeled data includes both input data and output data. For example, if we want to train a computer to recognize images of dogs 🐶, we would provide it with a set of labeled images where each image is labeled as either "dog" or "not dog". The computer would then use these labeled images to learn the patterns that distinguish dogs from other objects
#
# UNSML.EXAMPLE--
#
# Unsupervised learning is more like a self-discovery process where the computer tries to find patterns on its own ,Unsupervised learning can be used to group together similar data points based on their similarities, even if we don't know what those similarities are,and  used for data compression and image recognition. For example, it can be used to find patterns in images and compress them without losing important information,
#
# RML--
#
# Reinforcement learning, the computer learns by interacting with an environment, receiving rewards for good behavior and punishments for bad behavior. The goal is to learn a set of actions that will maximize the overall reward over time. Reinforcement learning has many applications in robotics, such as teaching a robot to walk or navigate through an environment.

# %% [markdown]
# Activity 2: True or False
#
# 1.Is supervised learning like having a teacher guide you every step of the way?
#
# 2.In supervised learning, labeled data includes both input data and output data.
#
# 3.Supervised learning is only used in image recognition applications.
#
#
#
# *ANSWERS*:
#
# 1.True
#
# 2.True
#
# 3.False

# %% [markdown]
# *** The role of data in machine learning is crucial***:
#
#
# -To build a successful machine learning model, we first need to collect and prepare the data. This involves several steps, including data collection, cleaning, and preprocessing. Let's explore each of these steps in more detail.
#
# - Data Collection: This involves gathering data from various sources such as databases, APIs, or web scraping. We need to ensure that the data is relevant and sufficient to build a machine learning model.
#
# - Data Cleaning: Once we have collected the data, we need to clean it by removing duplicates, handling missing values, and correcting any errors. This ensures that the data is accurate and consistent.
#
# - Data Preprocessing: Next, we need to preprocess the data by transforming it into a format suitable for machine learning algorithms. This involves tasks such as feature scaling, feature extraction, and data normalization.
#
# - The quality of the data and how it's prepared can have a significant impact on the performance of the machine learning model. A well-prepared dataset can lead to more accurate predictions and better insights.
#
# - So, it's essential to spend time collecting and cleaning the data, and then carefully preprocess it to ensure the machine learning model can learn from it effectively.

# %% [markdown]
# Fundamentals of statistical learning:
#
# bias-variance tradeoff, model complexity, and overfitting.
#
# ![Screenshot 2023-09-13 094333 2.jpg](data:image/jpeg;base64,...)
#
# * BIAS - Bias is simply defined as the inability of the model because of that there is some difference or error its actually the differnce between the actual and the prediction,There are 2 types of bias -LOW AND HIGH
#
# * VARIANCE - Variance refers to the changes in the model when using different portions of the training data set. Simply stated, variance is the variability in the model prediction It actualy if you use the ml model in different data set it aslo very it is also 2 type -high and low
#
# * TRADEOFF -This is the model which stay between these two
#
# * bias and variance is inversely proportional is that if u have low bais then u have high variance and high bias - low variance
#
# * Overfitting ▶- when ml model is too complex that means model wants to cover all the trainin points as 0 training error but in this case the variance is high this is overfitting
#
# * Underfitting ▶- low bias -high var
#
# * Tradeoff - The ml model between between them
#
# * look at the figure-a where we have low bias,high var in overfitting case and high bias ,low var in underfitting and the Green line is tradeoff
#
# * in figure-c we have overfitting as model cover all the training points so there trainin error is 0 but testing error may be high but the Green line is overfitting which is the perfect model for us as it has low bias and low variance

# %% [markdown]
# NOTES

# %% [markdown]
# *  Bias-variance tradeoff: In statistical learning, bias refers to how much the predictions of a model differ from the true values, and variance refers to how much the predictions of a model differ from each other when trained on different datasets,The bias-variance tradeoff refers to the balance between these two sources of error
#
# * Model complexity: Model complexity refers to how many parameters a model has and how flexible it is. A more complex model may fit the training data better, but it may also overfit and perform poorly on new data.
#
# * Overfitting: Overfitting occurs when a model is too complex and fits the training data too closely, leading to poor performance on new data. It happens when the model captures the noise in the training data, rather than the underlying patterns.

# %% [markdown]
# Evaluation metrics for machine learning models:
# "accuracy, precision, recall, F1 score, ROC curve, and AUC"

# %% [markdown]
# ![Screenshot 2023-09-13 103152.jpg](data:image/jpeg;base64,...)
#
# Sensitivity = recall

# %% [markdown]
# ![Screenshot 2023-09-13 103426.jpg](data:image/jpeg;base64,...)
#
# * Sensitivity is also referred as True Positive Rate or Recall
#
# * Specificity is also know as True Negative Rate.
#
# * Sensitivity  = 45/(45+20) = 69.23% .
#
# * specificity = 30/(30+5) = 85.71%
#
# * Precision = 45/(45+5)= 90%
#
# * RECALL = TP/TAP
#
# * PRECISION = TP/TPP
#
# * Accuracy = (45+30)/(45+20+5+30) = 75%
#
# * Accuracy = TP+TN/ ALLTOTAL
#
# * F1 score = 2 * ( P*R)/(P+R)

# %% [markdown]
#  🎯 F1 score: The F1 score is the harmonic mean of precision and recall. It provides a balance between the two metrics and is useful when there is an uneven class distribution.
#
# 🎯 ROC curve: The ROC (Receiver Operating Characteristic) curve is a graphical representation of the trade-off between the true positive rate (sensitivity) and false positive rate (1 - specificity) for different threshold values. It is useful for evaluating the performance of binary classification models across different thresholds.
#
# 🎯 AUC: The AUC (Area Under the Curve) is the area under the ROC curve and provides a single value that summarizes the overall performance of a binary classification model across all possible threshold values. An AUC value of 1 indicates a perfect model, while an AUC value of 0.5 indicates a random model.

# %% [markdown]
# **Activity 3**: Guess the Word
#
# 1.I refer to the balance between bias and variance in statistical learning, determining the tradeoff between the accuracy of predictions and their variability when trained on different datasets.Who am I?
#
# 2.I refer to the complexity and flexibility of a model, determined by the number of parameters it has.Who am I?
#
# 3.I occur when a model is too complex and fits the training data too closely, resulting in poor performance on new data.Who am I?
#
# 4.I am essential for building accurate and efficient machine learning models, involving concepts like bias-variance tradeoff, model complexity, and overfitting.Who am I?
#
# ANSWERS:-
#
# 1. Bias-Variance Tradeoff.
# 2. Model Complexity.
# 3. Overfitting.
# 4. Fundamentals of Statistical Learning.

# %% [markdown]
# **Thats all about ML introduction later we discuss about SML,UNML and their implimention read it carefully 2 times see u in the next chapter** ,LOVE FROM BIMAL_TS ,
