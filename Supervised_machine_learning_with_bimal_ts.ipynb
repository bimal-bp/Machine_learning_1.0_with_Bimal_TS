# %% [markdown]
# <a href="https://colab.research.google.com/github/bimal-bp/Machine_learning_1.0_with_Bimal_TS/blob/ML_MODELS/Supervised_machine_learning_with_bimal_ts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **supervised learning.** REGRESSION MODEL

# %% [markdown]
# ▶ Supervised learning is a type of machine learning where a model is trained to recognize patterns and make predictions using labeled data.
#
# * Supervised Models  is actually used for 2 types of data structure 1 is numerical data ( output will be in number predicting house price ) for this we use regression ml model and 2 is categorical where the prediction is about in alphabate ( he will take loan yes or no ) for this we use classificatio
#
# * both Regression and Clssification are in SML

# %% [markdown]
# * Throughout the course, participants will dive into regression models, exploring linear regression, polynomial regression, and the significance of regularization techniques like L1, L2, and Elastic Net. The knowledge gained from these topics will enable learners to predict continuous outcomes and understand the impact of model complexity on performance
#
# *  Moving on, the focus shifts to classification models, encompassing logistic regression, k-Nearest Neighbors, decision trees, and ensemble methods, including Random Forests and Gradient Boosting Machines. By grasping these techniques, students will be empowered to solve classification problems, distinguishing between multiple classes with confidence and precision

# %% [markdown]
# **USE CASE - **
#
#  According to recent studies, over 70% of businesses credit supervised learning with significant improvements in decision-making and performance across various industries.
#
# For instance , you're working for an e-commerce company striving to enhance customer satisfaction. By employing classification models such as logistic regression and k-Nearest Neighbors, the company identifies customer segments with distinct preferences, enabling personalized recommendations and targeted marketing strategies. 🛍️🎯
#
# Furthermore, you explore decision trees and ensemble methods like Random Forests, which have applications in finance, helping detect fraudulent transactions to safeguard customers and businesses. With supervised learning metrics, such as precision and recall, you assess model performance, ensuring reliable predictions in critical situations

# %% [markdown]
# **Primary Goals**-
#
# Accurate Predictions 🎯🔮: The main goal of supervised learning is to make accurate predictions using historical data. The models are trained to identify patterns and relationships in the data, which can then be used to predict future outcomes.
#
# Model Performance 🚀📈: The second goal is to ensure that the model performs well on new, unseen data. This is achieved by evaluating the model's performance using metrics such as accuracy, precision, recall, and F1-score.
#
# Feature Selection 🔍🔍: Another goal is to identify the most important features that contribute to the accuracy of the model. This is achieved by performing feature selection, which helps to eliminate redundant or irrelevant features.
#
# Model Interpretability 🤔🧐: The final goal is to make the model interpretable, which helps to understand how the model makes predictions. This is important for decision-making and to gain insights into the underlying patterns and relationships in the data.
#
# By achieving these primary goals, supervised learning models can help businesses and organizations make informed decisions and gain a competitive advantage.

# %% [markdown]
# ![Screenshot 2023-09-13 114525.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Regression models: linear regression, polynomial regression, regularization techniques (L1, L2, Elastic Net)**

# %% [markdown]
# ◼ Linear regression and polynomial regression are powerful techniques for modeling the relationship between two variables.where the target column is numerical
#
# * Linear regression is a simple but effective technique for modeling a linear relationship between two variables. It involves finding the line of best fit that minimizes the distance between the predicted values and the actual values. 🔍🤔
#
# * Polynomial regression, on the other hand, can capture more complex relationships between variables by adding higher-order terms. For example, a quadratic regression model could have a term for the squared value of the input variable. This can help to capture nonlinear relationships that would not be captured by a linear model. 🔍🤯
#
# * However, it's important to note that these models are not perfect and can have limitations, such as overfitting to the training data. This is where techniques like regularization (L1, L2, Elastic Net) come into play, which help to prevent overfitting and improve the accuracy of the model
#
# * Regularization techniques like L1, L2, and Elastic Net help to prevent overfitting and improve the accuracy of the model

# %% [markdown]
# ◼ Linear Regression:
#
# * df = pd.read_csv('placement.csv')
# * X = df.iloc[:,0:1]
# * y = df.iloc[:,-1]
# * from sklearn.model_selection import train_test_split
#
# * X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
# * from sklearn.linear_model import LinearRegression
# *lr = LinearRegression()
# *lr.fit(X_train,y_train)
# *lr.predict(X_test.iloc[0].values.reshape(1,1))
# *
# m = lr.coef_
# *b = lr.intercept_
# *y = mx + b
# * from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
# *print("MAE",mean_absolute_error(y_test,y_pred))
# *print("MSE",mean_squared_error(y_test,y_pred))
# * print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# * print("R2 score",r2_score(y_test,y_pred))
#
#  r2 = r2_score(y_test,y_pred)

# %% [markdown]
# LINEAR LINK - https://github.com/campusx-official/100-days-of-machine-learning/tree/main/day48-simple-linear-regression

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# * Red line is the linear model whose equation is  y = mx + b, m * 8.58 + b

# %% [markdown]
# ◼ multiple_linearl Regression:
#
#  * y = b0+b1x1+b2x2+b3x3
#
#  *from sklearn.linear_model import LinearRegression
#
#  *from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
#
#  *from sklearn.model_selection import train_test_split
#
#  *X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)
#
#  *lr.fit(X_train,y_train)
#
#  *LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#  *y_pred = lr.predict(X_test)
#
#  *MAE 33.086705281653586,
# MSE 1659.9139868998495,
# R2 score 0.7192978757875936
#
#  *
# lr.coef_ = (array([59.64518074, 13.20409431]))
#
#  *lr.intercept_=(-7.55491251398082)

# %% [markdown]
# MULTIPLE LINK -https://github.com/campusx-official/100-days-of-machine-learning/tree/main/day50-multiple-linear-regression

# %% [markdown]
# ◼  Polynomial-regression
#
# + import numpy as np
#
# - import matplotlib.pyplot as plt
#
# - from sklearn.model_selection import train_test_split
#
# - from sklearn.linear_model import LinearRegression,SGDRegressor
#
# - from sklearn.preprocessing import PolynomialFeatures,StandardScaler
#
# - from sklearn.metrics import r2_score
#
# - from sklearn.pipeline import Pipeline
#
# - X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
#
# - lr = LinearRegression()
#
# - lr.fit(X_train,y_train)
#
# - y_pred = lr.predict(X_test)
#
# - r2_score(y_test,y_pred)= (0.16130669964603517)
# - When we use linear regression to it it give the r2 score as 16% which is not good as it is a polynomial case
# -now using polynomial linear regression
# - poly = PolynomialFeatures(degree=2,include_bias=True)
# - X_train_trans = poly.fit_transform(X_train)
#
# - X_test_trans = poly.transform(X_test)
# - y_pred = lr.predict(X_test_trans)
# - r2_score(y_test,y_pred) = (0.8332188324158399) now we get 83%
# - print(lr.coef_) = ([[0.         0.89296931 0.78439465]])
# - print(lr.intercept_)=([1.99965238])

# %% [markdown]
# POLYNOMILA LINK- https://github.com/campusx-official/100-days-of-machine-learning/tree/main/day53-polynomial-regression

# %% [markdown]
# ![Screenshot 2023-09-13 144226.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# QUESTION:
#
# 1. Linear regression is a technique for modeling a ________ relationship between two variables.
#
# 2. Polynomial regression can capture more complex relationships by adding ________-order terms.
#
# answer -
#
# 1. Linear
#
# 2. Higher

# %% [markdown]
# # **Regularization techniques** (L1, L2, Elastic Net).

# %% [markdown]
# - Regularization techniques, such as L1, L2, and Elastic Net, are essential tools for improving the accuracy and performance of regression models. 🔮📊
#
# - L1 regularization, also known as Lasso, adds a penalty to the regression coefficients that shrinks some coefficients to zero. This helps to reduce the number of variables in the model and improve its interpretability. 🧐
#
# - L2 regularization, also known as Ridge, adds a penalty to the sum of squares of the regression coefficients. This helps to prevent overfitting and improve the generalization performance of the model. 🤔🤯
#
# - Elastic Net is a combination of L1 and L2 regularization, which combines the strengths of both methods. It helps to reduce the number of variables in the model while also preventing overfitting

# %% [markdown]
# L2 regularization, also known as Ridge:
#
# - in l2 reg lambda add in denomiter
#
# - L2 REG means add some value as λ  in loss function that brings our overfitting reduce and coffiecient reduce
#
# - The added value is λ whose value has (0-∞)
#
# - by adding of λ  the coffience comes toword zero but not zero
#
# - by increasing λ value the high coffienct decrease in high value and low s are normal decrease
#
# - small value of λ overfitting as bias decreases and variance increases
# - large value of λ underfitting as bias increase and variance decrease
#
# - After adding  λ (alpha) value the loss function comes towards 0 and shrinks
#
# - RIDGE named because as the solution stay on the ridge of both circles so it called ridge regression
# - loss = mse+λ(w)^2
# - Here actually there is great change in scalling lets say if for λ = 0 it may be 750 to -750 but after increase in λ it will come to 0.04 to -0.04

# %% [markdown]
#  L2 REGRESSION-https://github.com/campusx-official/100-days-of-machine-learning/blob/main/day55-regularized-linear-models/ridge-regression-key-understandings.ipynb

# %% [markdown]
# L1 regularization,(Lasso,)
#
# - in lasso λ stay on numertor so by adding λ value some coffients becomes 0
# - L1 helps in feature selection
# - if u increase λ value more to more lets say it stats from -2 then it will go 0 then after increase of λ value it will go to -5  it stops at only 0
# - sparcity comes in L1 but not in L2 as λ stay in differneent place
# - L1 gives the importance of columns but more increase in λ it will be overfitting
# - higher coffiecent affected more
# - λ increase overfitting(bias + ,variance -) and λ decrease uderfitting

# %% [markdown]
# L1 regression link - https://github.com/campusx-official/100-days-of-machine-learning/blob/main/day56-lasso-regression/lasso-regression-demo.ipynb

# %% [markdown]
# Elastic Net:
#
#  reg = ElasticNet(alpha=0.005,l1_ratio=0.9)
#
# reg.fit(X_train,y_train)
#
# y_pred = reg.predict(X_test)
#
# r2_score(y_test,y_pred)

# %% [markdown]
# # **LOVE FROM BIMAL_TS**
